# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# 'd:\Machine Learing\Fraud Detection\.venv\Scripts\pip.exe' was blocked by your organization's Device Guard policy.
# Contact your support person for more info.
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (2.5.1)
# Requirement already satisfied: matplotlib in .\.venv\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in .\.venv\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in .\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in .\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in .\.venv\Lib\site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in .\.venv\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in .\.venv\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df = pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 706.2 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.shape[0]
# Out:
# 6362620

# %%
round((df["isFraud"].value_counts()[1] / df.shape[0] ) * 100,2)
# Out:
# np.float64(0.13)

# %%
df["type"].value_counts().plot(kind="bar", title="Transaction Types", color = "skyblue")
plt.xlabel("Transaction Type")
plt.ylabel("Count")
plt.show()

# %%
fraud_by_type = df.groupby("type")["isFraud"].mean()

# %%
fraud_by_type
# Out:
# type
# CASH_IN     0.000000
# CASH_OUT    0.001840
# DEBIT       0.000000
# PAYMENT     0.000000
# TRANSFER    0.007688
# Name: isFraud, dtype: float64

# %%
fraud_by_type = df.groupby("type")["isFraud"].mean().sort_values(ascending=False)
fraud_by_type.plot(kind="bar", title="Fraud Rate by type", color="salmon")
plt.ylabel("Fraud Rate")
plt.show()

# %%
# amount statiticus
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
# histogram
sns.histplot(df["amount"], bins=100, kde=True, color="green")
plt.title("Transcation Amount Distribution (log scale)")
plt.xlabel("Log(Amount + 1)")
plt.ylabel("Count")
plt.show()

# %%
sns.boxplot(data=df[df["amount"] < 50000], x = 'isFraud', y = "amount")
plt.title("Amount vs isFraud(Filtered under 50k)")
plt.ylabel("amount")
# Out:
# Text(0, 0.5, 'amount')

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["balanceDiffOrig"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["balanceDiffDest"] = df["oldbalanceDest"] - df["newbalanceDest"]

# %%
(df["balanceDiffOrig"] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDest"] < 0).sum()
# Out:
# np.int64(2806464)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0

# %%
frauds_per_step = df[df["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values, label="Fraud per step")
plt.xlabel("Steps(Time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds over Time")
plt.grid(True)
plt.show()

# %%
df.drop(columns="step", inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# 2           181.00              0.0
# 3           181.00          21182.0
# 4         11668.14              0.0

# %%
top_senders = df["nameOrig"].value_counts().head(10)
top_receivers = df["nameDest"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df["isFraud"] == 1]["nameOrig"].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER", "CASH_OUT"])]

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types, x="type", hue="isFraud")
plt.title("Fraud Distribution in Transfer & Cash_out")
plt.show()

# %%
corr = df[["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "isFraud"]].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap/Matrix")
plt.show()

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"] > 0) &
    (df["newbalanceOrig"] == 0) &
    (df["type"].isin(["TRANSFER", "CASH_OUT"]))
]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.head()
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145          181.0             0.0
# 3   CASH_OUT     181.00   C840083671          181.0             0.0
# 15  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     balanceDiffOrig  balanceDiffDest
# 2             181.0             0.00
# 3             181.0         21182.00
# 15          15325.0        -46430.44
# 19            705.0         22425.00
# 24          10835.0      -2712905.89

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %% [markdown]
# **FEATURE ENGINEERING**
#
# ---
#
#
#
# ---

# %%
# !pip install scikit-learn 
# !pip install joblib
# !pip install streamlit
# Out:
# Requirement already satisfied: scikit-learn in .\.venv\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in .\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in .\.venv\Lib\site-packages (from scikit-learn) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in .\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: joblib in .\.venv\Lib\site-packages (1.5.3)
# Requirement already satisfied: streamlit in .\.venv\Lib\site-packages (1.59.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in .\.venv\Lib\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\.venv\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in .\.venv\Lib\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in .\.venv\Lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\.venv\Lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in .\.venv\Lib\site-packages (from streamlit) (2.5.1)
# Requirement already satisfied: packaging>=20 in .\.venv\Lib\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in .\.venv\Lib\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\.venv\Lib\site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\.venv\Lib\site-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=3.20 in .\.venv\Lib\site-packages (from streamlit) (7.35.1)
# Requirement already satisfied: pyarrow>=7.0 in .\.venv\Lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in .\.venv\Lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\.venv\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in .\.venv\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in .\.venv\Lib\site-packages (from streamlit) (4.16.0)
# Requirement already satisfied: starlette>=0.40.0 in .\.venv\Lib\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in .\.venv\Lib\site-packages (from streamlit) (0.51.0)
# Requirement already satisfied: httptools>=0.6.3 in .\.venv\Lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in .\.venv\Lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: python-multipart>=0.0.10 in .\.venv\Lib\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in .\.venv\Lib\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in .\.venv\Lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\.venv\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in .\.venv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\.venv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in .\.venv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.23.0)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\.venv\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\.venv\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in .\.venv\Lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# 2           181.00              0.0
# 3           181.00          21182.0
# 4         11668.14              0.0

# %%
df_model = df.drop(["nameOrig", "nameDest", "isFlaggedFraud"], axis=1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrig  balanceDiffDest
# 0             0.0        0          9839.64              0.0
# 1             0.0        0          1864.28              0.0
# 2             0.0        1           181.00              0.0
# 3             0.0        1           181.00          21182.0
# 4             0.0        0         11668.14              0.0

# %%
# Categorical and numerical types
categorical_cols = ["type"]
numerical_cols = ["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest"]

# %%
print(df_model["isFraud"].isnull().sum())
# Out:
# 0

# %%
print(df_model[df_model["isFraud"].isnull()])
# Out:
# Empty DataFrame
# Columns: [type, amount, oldbalanceOrg, newbalanceOrig, oldbalanceDest, newbalanceDest, isFraud, balanceDiffOrig, balanceDiffDest]
# Index: []

# %%
print(df_model["isFraud"].isnull().sum())
# Out:
# 0

# %%
df_model = df_model.dropna(subset=["isFraud"])

X = df_model.drop("isFraud", axis=1)
y = df_model["isFraud"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,
    # random_state=42
)

# %%
# Preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_cols),
        ("cat", OneHotEncoder(drop="first"), categorical_cols)

    ],
    remainder="drop"
)

# %%
# Model pipeline
pipeline = Pipeline([
    ("prep", preprocessor),
    ("classifier", LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
# Train the model
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97   1906322
#            1       0.02      0.95      0.04      2464
#
#     accuracy                           0.94   1908786
#    macro avg       0.51      0.95      0.51   1908786
# weighted avg       1.00      0.94      0.97   1908786

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1797833,  108489],
#        [    130,    2334]])

# %%
pipeline.score(X_test, y_test) * 100
# Out:
# 94.30952448310079

# %%
import joblib

joblib.dump(pipeline, "fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']
